# %%
from src.tree import leaf_page_to_graph

# %%
leaf_page_to_graph("/Wonder_of_Stardom_Championship")
# Out:
#         <iframe
#             width="100%"
#             height="620"
#             src="data:text/html;charset=utf-8;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
leaf_page_to_graph("/Mork")
# Out:
#         <iframe
#             width="100%"
#             height="620"
#             src="data:text/html;charset=utf-8;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
leaf_page_to_graph("/Ayuda:Espacio_de_nombres")
# Out:
#         <iframe
#             width="100%"
#             height="620"
#             src="data:text/html;charset=utf-8;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
