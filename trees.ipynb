# %%
from src.scrapping import all_the_ways_lead_to
from src.tree import *

# %%
testing = all_the_ways_lead_to("/Wonder_of_Stardom_Championship")
tree = add_to_tree(testing)
tree.basic_print()
# Out:
# /Filosofía
#   /Proposición
#     /Hipótesis_(método_científico)
#       /Experimento
#         /Ciencias_naturales
#           /Física
#             /Física_clásica
#               /Materia
#                 /Interpretación#Ciencias_naturales_y_formales
#                   /Idea
#                     /Creatividad
#                       /Investigación_científica
#                         /Metodología
#                           /Método_científico
#                             /Ciencia
#                               /Psicología
#                                 /Actividad
#                                   /Economía
#                                     /Factores_de_producción
#                                       /Empresa
#                                         /Emprendedor
#                                           /Negocio
#                                             /Tiempo_libre
#                                               /Entretenimiento
# ...

# %%
testing = all_the_ways_lead_to("/Índice_de_Jaccard")
tree = add_to_tree(testing, tree)
tree.basic_print()
# Out:
# /Filosofía
#   /Proposición
#     /Hipótesis_(método_científico)
#       /Experimento
#         /Ciencias_naturales
#           /Física
#             /Física_clásica
#               /Materia
#                 /Interpretación#Ciencias_naturales_y_formales
#                   /Idea
#                     /Creatividad
#                       /Investigación_científica
#                         /Metodología
#                           /Método_científico
#                             /Ciencia
#                               /Psicología
#                                 /Actividad
#                                   /Economía
#                                     /Factores_de_producción
#                                       /Empresa
#                                         /Emprendedor
#                                           /Negocio
#                                             /Tiempo_libre
#                                               /Entretenimiento
# ...

# %%
testing = all_the_ways_lead_to("/Mork")
tree = add_to_tree(testing, tree)
tree.basic_print()
# Out:
# /Filosofía
#   /Proposición
#     /Hipótesis_(método_científico)
#       /Experimento
#         /Ciencias_naturales
#           /Física
#             /Física_clásica
#               /Materia
#                 /Interpretación#Ciencias_naturales_y_formales
#                   /Idea
#                     /Creatividad
#                       /Investigación_científica
#                         /Metodología
#                           /Método_científico
#                             /Ciencia
#                               /Psicología
#                                 /Actividad
#                                   /Economía
#                                     /Factores_de_producción
#                                       /Empresa
#                                         /Emprendedor
#                                           /Negocio
#                                             /Tiempo_libre
#                                               /Entretenimiento
# ...
